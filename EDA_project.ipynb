# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
# %matplotlib inline
sns.set(style="whitegrid")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'/Users/ajeetkumarmishra/Downloads/heart_disease_uci-1.csv')

# %%
print('The Shape of the Dataset: ',df.shape)
# Out:
# The Shape of the Dataset:  (920, 16)

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
print('the shape of the dataset :',df.shape)
# Out:
# the shape of the dataset : (920, 16)

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
# Checcking the Datatype Columns
df.dtypes
# Out:
# id            int64
# age           int64
# sex          object
# dataset      object
# cp           object
# trestbps    float64
# chol        float64
# fbs          object
# restecg      object
# thalch      float64
# exang        object
# oldpeak     float64
# slope        object
# ca          float64
# thal         object
# num           int64
# dtype: object

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df['num'].nunique()
# Out:
# 5

# %%
df['num'].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
df.nunique() #Finding the number of unique values columns-wise
# Out:
# id          920
# age          50
# sex           2
# dataset       4
# cp            4
# trestbps     61
# chol        217
# fbs           2
# restecg       3
# thalch      119
# exang         2
# oldpeak      53
# slope         3
# ca            4
# thal          3
# num           5
# dtype: int64

# %%
df['age'].value_counts() #count of unique values in age column
# Out:
# 54    51
# 58    43
# 55    41
# 56    38
# 57    38
# 52    36
# 62    35
# 51    35
# 59    35
# 53    33
# 60    32
# 61    31
# 48    31
# 63    30
# 50    25
# 41    24
# 46    24
# 43    24
# 64    22
# 49    22
# 65    21
# 44    19
# 47    19
# 45    18
# 42    18
# 38    16
# 67    15
# 39    15
# 69    13
# 40    13
# 66    13
# 35    11
# 37    11
# 68    10
# 34     7
# 70     7
# 74     7
# 36     6
# 32     5
# 71     5
# 72     4
# 29     3
# 75     3
# 31     2
# 33     2
# 76     2
# 77     2
# 30     1
# 28     1
# 73     1
# Name: age, dtype: int64

# %%
df.groupby('sex')['num'].value_counts()
# Out:
# sex     num
# Female  0      144
#         1       30
#         2       10
#         3        8
#         4        2
# Male    0      267
#         1      235
#         2       99
#         3       99
#         4       26
# Name: num, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="sex",hue="num",data=df)
plt.show()

# %%
ax=sns.catplot(x="num",col="sex",data=df,kind="count",height=5,aspect=1)

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(y="num",hue="sex",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="num",data=df,palette="Set3")
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="num",data=df,facecolor=(0,0,0,0),linewidth=5,edgecolor=sns.color_palette("BrBG", 2))
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="num",hue='fbs',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="num",hue="exang",data=df)
plt.show()

# %%
correlation=df.corr()

# %%
correlation['num'].sort_values(ascending=False)
# Out:
# num         1.000000
# ca          0.516216
# oldpeak     0.443084
# age         0.339596
# id          0.273552
# trestbps    0.122291
# chol       -0.231547
# thalch     -0.366265
# Name: num, dtype: float64

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].value_counts()
# Out:
# asymptomatic       496
# non-anginal        204
# atypical angina    174
# typical angina      46
# Name: cp, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="cp",data=df)
plt.show()

# %%
df.groupby('cp')['num'].value_counts()
# Out:
# cp               num
# asymptomatic     1      197
#                  0      104
#                  2       89
#                  3       83
#                  4       23
# atypical angina  0      150
#                  1       19
#                  3        3
#                  2        2
# non-anginal      0      131
#                  1       37
#                  3       18
#                  2       14
#                  4        4
# typical angina   0       26
#                  1       12
#                  2        4
#                  3        3
#                  4        1
# Name: num, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.countplot(x="cp",hue="num",data=df)
plt.show()

# %%
ax=sns.catplot(x="num",col="cp",data=df,kind="count",height=8,aspect=1)

# %%
df['thalch'].nunique()
# Out:
# 119

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalch']
ax=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalch']
x=pd.Series(x,name="thalch variable")
ax=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalch']
ax=sns.distplot(x,bins=10,vertical=True)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalch']
x=pd.Series(x,name="thalch variable")
ax=sns.kdeplot(x)
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalch']
x=pd.Series(x,name="thalch variable")
ax=sns.kdeplot(x,shade=True,color='r')
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['thalch']
ax=sns.distplot(x,kde=False,rug=True,bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="num",y="thalch",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="num",y="thalch",data=df,jitter=0.01)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x="num",y="thalch",data=df)
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a=sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
plt.show()

# %%
num_var=['age','trestbps','chol','thalch','oldpeak','num']
sns.pairplot(df[num_var],kind='scatter',diag_kind='hist')
plt.show()

# %%
df['age'].nunique()
# Out:
# 50

# %%
df['age'].describe()
# Out:
# count    920.000000
# mean      53.510870
# std        9.424685
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['age']
ax=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x="num",y='age',data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x="num",y="age",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x="age",y="trestbps",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x="age",y="trestbps",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x="age",y="chol",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x="age",y="chol",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x="chol",y="thalch",data=df)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.regplot(x="chol",y="thalch",data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
pd.notnull(df).all().all()
# Out:
# False

# %%
df['age'].describe()
# Out:
# count    920.000000
# mean      53.510870
# std        9.424685
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df["age"])
plt.show()

# %%
df['trestbps'].describe()
# Out:
# count    861.000000
# mean     132.132404
# std       19.066070
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df["trestbps"])
plt.show()

# %%
df['chol'].describe()
# Out:
# count    890.000000
# mean     199.130337
# std      110.780810
# min        0.000000
# 25%      175.000000
# 50%      223.000000
# 75%      268.000000
# max      603.000000
# Name: chol, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df["chol"])
plt.show()

# %%
df['thalch'].describe()
# Out:
# count    865.000000
# mean     137.545665
# std       25.926276
# min       60.000000
# 25%      120.000000
# 50%      140.000000
# 75%      157.000000
# max      202.000000
# Name: thalch, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df["thalch"])
plt.show()

# %%
df['oldpeak'].describe()
# Out:
# count    858.000000
# mean       0.878788
# std        1.091226
# min       -2.600000
# 25%        0.000000
# 50%        0.500000
# 75%        1.500000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x=df["oldpeak"])
plt.show()
